# %% [markdown]
# # Bewertung für Bachelorarbeit
# Autorin:  Frau Ingrid Tchilibou
#
# Bewerter: Herr Michael Tebbe

# %% [markdown]
# ### 1.1 Datensatz von Annotation laden

# %%
import json
import import_ipynb
import extract_hypernyms as EH
# read file
if __name__ == '__main__':
    
    #data loaded
    with open('export200.json', 'r') as myfile:
        data = myfile.read()
    ideen_list   = json.loads(data)
# Out:
# importing Jupyter notebook from extract_hypernyms.ipynb

# %% [markdown]
# ### 1.2 Ideen Wörterbuch (key = (nummerId , Id) , Value = Content)
#
#  Alle 200 Ideen werden in der ideenDict mit entsprechen nummerID und Id gespeichert

# %%
ideenDict    = EH.get_dictionaryIdee(ideen_list)

# %% [markdown]
# ### 1.3 DictionaryTree: Beziehungen zwischen Hypernym
# Key   = ein Hypernym(Eltern Knoten)
#
# Value = List von Hypernyme (Kinder Knoten die als Direkthypernym der Eltern Knoten haben)
#
# i)  Verfügbare Funktionen
#
#     a) EH.build_tree(dictionaryTree) Zeigt der gesamte Baum
#
#     b) Ein Spezifisches Knoten mit  Kinder als unterbaum anzeigen lassen
#           EH.build_part_of_tree_(Tree,knoten) wobei knoten den form synset.pos.id hat
#           Beispiel: EH.build_part_of_tree(dictionaryTree, "entity.n.01")

# %%
synsetsList    = EH.get_synsetsList(ideen_list)   #key = Synset, Value = [list von ID]
dictionaryTree = EH.analyse(synsetsList)

# %% [markdown]
# ### 1.4 SynsetsList,hypernymList, ideen_synset, ideen_hypernym Wörterbücher
#
# a) Verfügbare Funktionen:
#
#     i) EH.plot_balken:hypernym(hypernymList,prozent):
#     Balkendiagramm Darstellung: Anzahl von Ideen pro Hypernyme
#     Hypernyme mit Anzahl an Ideen weniger als "prozent"  werden in Others gruppiert.
#     Und "Others" wird als eine geordnete Liste von der kleinsten bis zur größten angezeigt.
#     Beispiel: EH.plot_balken_hypernym(hypernymList,20)
#
#     ii) EH.plot_hypernyme_fenster(hypernymList,minimum,maximum)
#     Hypernym mit Anzahl an Ideen Zwischen minimum and maximum
#     Tabelle mit Anzahl an Ideen, Überschneidung und Anzahl an Hypernyme
#     Beispiel: EH.plot_hypernyme_fenster(hypernymList,26,40)
#
#     iii) EH.plot_mapping_idee_Synstet(ideen_synset,prozent)
#      Balkendiagramm Darstellung: Anzahl von Synset pro Idee
#      IdeenId mit Anzahl an Synsets weniger als "prozent"  werden in Others gruppiert.
#      Und "Others" wird als eine geordnete Liste von der kleinsten bis zur größten angezeigt.
#
#     iiii) EH.plot_mapping_idee_Hypernym(ideen_hypernym,prozent)
#         Balkendiagramm Darstellung: Anzahl an Hypernyme pro Idee
#         IdeenId mit Anzahl an Hypernyme  weniger als "prozent"  werden in Others gruppiert.
#         Und "Others" wird als eine geordnete Liste von der kleinsten bis zur größten angezeigt.

# %%
hypernymList      = EH.get_hypernymDict(synsetsList) #Key = hypernym ,     Value = [list von ID]
ideen_synset      = EH.mapping_idee_to_synsets(ideen_list) #key = (nummerId,Id) Value = [Listsynsets]
ideen_hypernym    = EH.mapping_idee_to_hypernym(ideen_synset) # key = (nummerId,Id)  Value = [Listhypernymen]
print("Anzahl Synsets", len(synsetsList.keys()))
print("Anzahl Hypernym", len(hypernymList.keys()))
# Out:
# Anzahl Synsets 1289
# Anzahl Hypernym 2208

# %% [markdown]
# #### Frage 1: Welche Themenbereiche gibt es in dem Datensatz ?

# %%
EH.plot_hypernyme_fenster(hypernymList,5,7)
# Out:
#   Anzahl an Ideen Überschneidung Anzahlhypernyme
# 0               5              0              63
# 1               6              0              32
# 2               7              0              28

# %% [markdown]
# 59 ideas: application, technology, profession -> technology can be used to do a job
# rest maybe: tech can be used at home, not on the job (e.g. sports)

# %%
#Antwort: 
#print("Synsets", synsetsList.keys())
#print("Hypernyms", hypernymList.keys())
EH.plot_balken_hypernym(hypernymList,10)
# Out:
# Others:  ['livestock.n.01', 'used.a.01', 'trait.n.01', 'demeanor.n.01', 'manner.n.02', 'say.v.09', 'ideal.n.01', 'exemplar.n.01', 'pattern.n.05', 'condemnable.s.01', 'enrollee.n.01', 'student.n.01', 'intellectual.n.01', 'scholar.n.01', 'perform.v.03', 'carry_through.v.01', 'do.v.03', 'research.n.01', 'research.v.01', 'physical.s.05', 'live.v.07', 'top.n.01', 'top.n.02', 'topographic_point.n.01', 'peak.n.04', 'degree.n.02', 'acme.n.01', 'intensity.n.02', 'top.n.06', 'top.v.06', 'top.a.01', 'succeed.v.01', 'achieve.v.01', 'company.n.01', 'company.n.04', 'set.n.05', 'party.n.03', 'company.n.09', 'discriminate.v.02', 'isolate.v.01', 'separate.v.02', 'sequester.v.05', 'expect.v.03', 'expected.a.01', 'behavior.n.02', 'employee.n.01', 'anticipate.v.02', 'know.v.03', 'anticipate.v.03', 'move.v.07', 'work.n.05', 'work.v.03', 'day.n.02', 'calendar_day.n.01', 'day.n.03', 'day.n.07', 'establish.v.08', 'fair.s.02', 'fair.a.04', 'alignment.n.02', 'true.n.01', 'true.s.05', 'true.s.08', 'true.s.10', 'support.n.10', 'structural_member.n.01', 'upright.n.01', 'post.n.04', 'standard.n.05', 'malignancy.n.01', 'malignant_tumor.n.01', 'cancer.n.01', 'growth.n.06', 'tumor.n.01', 'earlier.s.01', 'early.a.01', 'early.s.06', 'spatial_property.n.01', 'shape.n.01', 'form.n.07', 'example.n.01', 'know.v.07', 'normal.a.01', 'liver.n.03', 'liver.n.04', 'look.v.09', 'scan.v.02', 'search.v.04', 'scan.v.03', 'perform.v.01', 'declaim.v.01', 'scan.v.06', 'microscopic.s.03', 'present.a.02', 'engineering.n.02', 'direction.n.01', 'get.v.03', 'mean.v.01', 'drive.v.11', 'shelter.v.01', 'house.v.02', 'inside.s.03', 'baby.n.02', 'young.n.01', 'young_mammal.n.01', 'baby.n.06', 'rocker.n.01', 'furnishing.n.02', 'furniture.n.01', 'seat.n.03', 'chair.n.01', 'rocking_chair.n.01', 'vibration.n.01', 'gesticulate.v.01', 'spacing.n.02', 'distance.n.01', 'nearness.n.01', 'proximity.n.01', 'proximity.n.02', 'custodian.n.01', 'caretaker.n.01', 'know.v.04', 'benefit.n.02', 'comfort.n.01', 'able.s.02', 'directly.r.01', 'deep.a.01', 'deep.s.05', 'profoundly.r.01', 'low.r.01', 'existent.a.01', 'treat.v.01', 'wrong.v.01', 'victimize.v.01', 'cheat.v.01', 'overcharge.v.01', 'contend.v.06', 'fight.v.02', 'resist.v.02', 'deep.n.03', 'extent.n.02', 'depth.n.01', 'read.v.01', 'understand.v.03', 'speech.n.02', 'conversation.n.01', 'talk.n.01', 'prize.v.01', 'recognize.v.09', 'honor.v.01', 'toast.v.02', 'give.v.34', 'time.n.02', 'ear.n.04', 'piece.n.01', 'wear.v.02', 'adventurer.n.01', 'explorer.n.01', 'far.a.01', 'universe.n.01', 'hiker.n.01', 'mountaineer.n.01', 'climber.n.04', 'health.n.01', 'good_health.n.01', 'condition.n.05', 'fitness.n.02', 'hunter.n.01', 'tracker.n.01', 'unite.v.03', 'combined.a.01', 'temper.n.02', 'fact.n.02', 'index.n.02', 'body_mass_index.n.01', 'test.v.01', 'address.v.01', 'ask.v.05', 'question.v.03', 'examine.v.04', 'quiz.v.01', 'aspect.n.01', 'side.n.06', 'hand.n.07', 'sized.a.01', 'door.n.03', 'door.n.05', 'open.v.01', 'unlock.v.01', 'house.n.12', 'family.n.01', 'kin.n.02', 'genealogy.n.01', 'lineage.n.01', 'family.n.04', 'pace.n.01', 'survive.v.01', 'surviving.s.01', 'lifelike.s.02', 'visitor.n.01', 'outfield.n.01', 'proceed.v.02', 'head.v.01', 'supporting_structure.n.01', 'support.n.07', 'foundation.n.03', 'restraint.n.06', 'catch.n.06', 'recognize.v.02', 'recognize.v.04', 'temporal_property.n.01', 'temporal_arrangement.n.01', 'timing.n.01', 'approach.n.07', 'save.v.03', 'produce.v.01', 'give_birth.v.01', 'prematurely.r.01', 'internal_organ.n.01', 'heart.n.02', 'organic_process.n.01', 'bodily_process.n.01', 'breathing.n.01', 'oxygen.n.01', 'grade.n.02', 'much.r.02', 'check.v.02', 'screen.v.01', 'night.n.03', 'any.s.01', 'alarming.a.01', 'thing.n.08', 'change.n.06', 'announce.v.01', 'report.v.03', 'report.v.05', 'all.a.01', 'connection.n.03', 'attachment.n.04', 'ligament.n.02', 'wire.n.01', 'unmake.v.01', 'destroy.v.01', 'extinguish.v.04', 'wave.n.01', 'explain.v.02', 'villain.n.01', 'rogue.n.01', 'provide.v.07', 'guidance.n.01', 'unfamiliar.a.01', 'assist.v.02', ...

# %% [markdown]
# EH.plot_balken_hypernym(hypernymList,5)
# Topics:
# bad person
# invesigation
# building
# container
# mammal....
# 11 - 16 occurences
#
# EH.plot_balken_hypernym(hypernymList,10)
# Topics:
# residence
# home
# ...
# - technology

# %% [markdown]
# #### Frage 2: Finde unerwartete Ideen bzw. unerwartete Themenbereiche oder Outlier (5 Stück)

# %%
#Antwort:
Livestock, Student

# %% [markdown]
# ### 1.5 Daten Reduktion: Pro Ideen genau 1 Synset
#     Synset die am Wenigstens in Datensatz vorkommt bzw. genau ein mal!
#
#     a) verfügbare Funktionnen:
#
#        i) EH.plot_occurence_synset(synsets_occurence,prozent)
#         Balkendiagramm Darstellung: Pro Synset wird die Anzahl an wiederholung in der Datensatz angezeigt.
#         Synsets mit Anzahl an Occurence weniger als "prozent"  werden in Others gruppiert.
#         Und "Others" wird als eine geordnete Liste von der kleinsten bis zur größten angezeigt.
#
#        ii) Alle in 1.3 genanten Tree Funktionnen

# %%
synsets_occurence        = EH.occurence_of_synset(ideen_synset) #key = Synset, Value = Anzahl von vorkommen
ideen_synsetList_clearly = EH.ideen_synsetDict_clearly(ideen_synset, synsets_occurence)#key = (nummerId,Id), Value = [ein Synset]
synsetList_clearly       = EH.synsetDict_clearly(ideen_synsetList_clearly, synsetsList )#key = Synset, Value = [list von ID] 
dictionaryTree_clearly   = EH.analyse(synsetList_clearly)

# %% [markdown]
# #### Frage 3: Mit dem neuen Daten was sind Die Themenbereiche?

# %%
#Antwort

hypernymList_clearly      = EH.get_hypernymDict(synsetList_clearly)
EH.plot_balken_hypernym(hypernymList_clearly,1)

#filter through hypernyms and choose tzhe ones that might be topics
# Out:
# Others:  ['livestock.n.01', 'used.a.01', 'malignancy.n.01', 'malignant_tumor.n.01', 'cancer.n.01', 'growth.n.06', 'tumor.n.01', 'line.n.11', 'path.n.03', 'direction.n.01', 'relative.n.01', 'offspring.n.01', 'baby.n.02', 'able.s.02', 'deep.a.01', 'read.v.01', 'adventurer.n.01', 'condition.n.03', 'fortune.n.04', 'good_fortune.n.01', 'prosperity.n.02', 'wellbeing.n.01', 'health.n.01', 'abstraction.n.01', 'right.n.01', 'entree.n.02', 'door.n.03', 'survive.v.01', 'measure.n.02', 'definite_quantity.n.01', 'number.n.02', 'outfield.n.01', 'save.v.03', 'fix.v.12', 'provide.v.07', 'unfamiliar.a.01', 'work.v.01', 'assist.v.02', 'creativity.n.01', 'imagination.n.01', 'status.n.01', 'social_station.n.01', 'place.n.10', 'quality.n.01', 'inhumaneness.n.01', 'atrocity.n.01', 'meet.v.01', 'some.a.01', 'watch.v.06', 'meet.v.07', 'battlefield.n.01', 'vote.n.02', 'election.n.01', 'primary.n.01', 'place_of_business.n.01', 'mercantile_establishment.n.01', 'plaza.n.02', 'treat.v.03', 'analyze.v.04', 'class.n.03', 'upper_class.n.01', 'elite.n.01', 'district.n.01', 'administrative_district.n.01', 'reservation.n.01', 'representation.n.10', 'model.n.09', 'discovery.n.01', 'detection.n.02', 'military.a.02', 'therapist.n.01', 'position.n.07', 'placement.n.01', 'tandem.n.01', 'see.v.05', 'identify.v.03', 'way.n.06', 'road.n.01', 'thoroughfare.n.01', 'street.n.01', 'autonomous.s.02', 'rodent.n.01', 'increase.n.02', 'belief.n.01', 'doctrine.n.01', 'teaching.n.02', 'analyze.v.01', 'diagnose.v.01', 'calculator.n.01', 'immediate.s.01', 'destroy.v.02', 'get.v.01', 'find.v.03', 'locate.v.01', 'pinpoint.v.01', 'travel.v.05', 'modular.s.01', 'pet.n.01', 'wrongdoing.n.02', 'transgression.n.01', 'crime.n.01', 'felony.n.01', 'capture.n.04', 'kidnapping.n.01', 'creation.n.02', 'product.n.02', 'movie.n.01', 'social_event.n.01', 'show.n.03', 'different.s.05', 'movement.n.11', 'transportation.n.02', 'mix.v.05', 'compound.v.05', 'integrate.v.01', 'learn.v.02', 'know.v.01', 'sense.v.04', 'geographic.a.01', 'runner.n.09', 'ski.n.01', 'create_by_mental_act.v.01', 'imagine.v.01', 'think.v.05', 'solid.n.01', 'food.n.02', 'fish.n.02', 'motion.n.03', 'gesture.n.01', 'drive.v.02', 'cooperation.n.01', 'conformity.n.02', 'keeping.n.01', 'remotely.r.02', 'trouble.n.03', 'misfortune.n.01', 'mishap.n.02', 'accident.n.01', 'injury.n.02', 'damage.n.01', 'densely.r.02', 'small.r.01', 'plant.v.01', 'afforest.v.01', 'excellent.s.01', 'transfer.v.02', 'convey.v.03', 'communicate.v.01', 'request.v.01', 'apply.v.03', 'spy.v.03', 'detect.v.01', 'see.v.19', 'capital.n.01', 'stock.n.01', 'statement.n.01', 'announcement.n.02', 'program.n.05', 'unfitness.n.01', 'disability.n.01', 'substance.n.01', 'material.n.01', 'animal_material.n.01', 'animal_product.n.01', 'animal_skin.n.01', 'hide.n.01', 'part.n.01', 'calmly.r.01', 'mechanism.n.05', 'control.n.09', 'switch.n.01', 'push_button.n.01', 'doorbell.n.01', 'point.n.02', 'geographic_point.n.01', 'workplace.n.01', 'heat.n.01', 'observe.v.06', 'measurement.n.01', 'travel.v.02', 'nongovernmental_organization.n.01', 'mission.n.01', 'physicist.n.01', 'residency.n.01', 'occupancy.n.01', 'inhabitancy.n.01', 'camping.n.01', 'be.v.01', 'track.n.03', 'sense.n.03', 'sensitivity.n.01', 'exteroception.n.01', 'sight.n.03', 'modality.n.03', 'relationship.n.03', 'account.n.03', 'in.r.01', 'property.n.01', 'things.n.01', 'cover.v.01', 'coat.v.01', 'metal.v.01', 'assemble.v.03', 'take.v.21', 'assume.v.06', 'appropriate.v.02', 'regenerate.v.01', 'replace.v.01', 'field.n.01', 'yard.n.02', 'equal.v.01', 'match.v.01', 'meet.v.05', 'suit.v.01', 'adult.n.01', 'professional.n.01', 'health_professional.n.01', 'medical_practitioner.n.01', 'doctor.n.01', 'body.n.02', 'public.n.02', 'attention.n.05', 'concentration.n.05', 'study.n.04', 'movement.n.03', 'change_of_location.n.01', 'descent.n.01', 'slide.n.02', 'avalanche.n.01', 'be.v.03', 'lie.v.01', 'orient.v.01', 'get_the_better_of.v.01', 'beat.v.01', 'cream.v.02', 'institution.n.01', 'educational_institution.n.01', 'school.n.01' ...

# %% [markdown]
# ### 1.6 Abstraktionsgrad eine Idee
# Verfügbare Funktionnen:
#
#     i) EH.Top_Abstract_and_concret(Abstractionsgrad,ideenDict,top)
#       gibt ein Tupel mit top Abstrakte und Konkrete Ideen
#       beispiel: listTop2_Abstrakt,listTop2_KonKret = EH.Top_Abstract_and_concret(Abstractionsgrad,ideenDict,2)

# %%
Abstractionsgrad = EH.Abstractionsgradfunc(ideen_synset)  #key = (numId,Id) value = distance

# %% [markdown]
# #### Frage 4: Was sind die abstraktesten Ideen in dem Datensatz? Was sind die konkretesten Ideen in dem Datensatz? (5 Stück)

# %%
#Antwort
listTop2_Abstrakt,listTop2_KonKret = EH.Top_Abstract_and_concret(Abstractionsgrad,ideenDict,5)

print('abstract:', listTop2_Abstrakt)
print()
print('konkret: ', listTop2_KonKret)
# Out:
# abstract: [(17, 'as a sensor on a car'), (74, 'Airplane navigation in low visibility'), (94, "Doorbell security systems that ID what's on the porch"), (95, 'I will see where an intruder is in my home at night.'), (163, 'I will know if a stranger is in my home.')]
#
# konkret:  [(24, 'Could be used by the Space Station to detect and analyze oncoming objects.'), (83, 'Look through forests to see all of the different animals and if there are any that have not been discovered'), (151, 'It can be used for next generation Microsoft Kinect.'), (174, 'Astronomical observations: detecting objects in otherwise poorly monitored sections of the sky.'), (184, "the device would be useful for predictive behaviors as an app for example, say someone wants to create a better lifestyle for themselves, they want to go to the gym more often or avoid fast food, they will be triggered by the app to make clear they've breached their range and must revert, perhaps it could also notify another person to prevent them from doing so. You could set parameters such as local fast food places and when the movement is predicted to be in that direction you're notified and made to stop.")]

# %% [markdown]
# #### Frage 5: Welche wichtigen Informationen über die Daten können wir mit Hilfe der bereitgestellten Wörterbücher noch erhalten?

# %% [markdown]
# #Antwort
# find rare ideas by looking at overlaps between synsets. Hypothesis: rare ideas produce 'strange' overlaps
#
# synsets per idea
# k
# tree of one idea
#
# compare two trees
#
# use corpus-based methods to filter out uninformative topics
